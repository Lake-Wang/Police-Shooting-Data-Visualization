# %%
import pandas as pd

# %%
main_data = pd.read_csv('shootings.csv')
main_data
# Out:
#        manner_of_death       armed   age gender      race           city  \
# 0                 shot         gun  53.0      M     Asian        Shelton
# 1                 shot         gun  47.0      M     White          Aloha
# 2     shot and Tasered     unarmed  23.0      M  Hispanic        Wichita
# 3                 shot  toy weapon  32.0      M     White  San Francisco
# 4                 shot    nail gun  39.0      M  Hispanic          Evans
# ...                ...         ...   ...    ...       ...            ...
# 4890              shot       Taser  27.0      M     Black        Atlanta
# 4891              shot         gun  23.0      M     Black    Crown Point
# 4892              shot     unarmed  25.0      F     White        Sedalia
# 4893              shot         gun  22.0      M     White    Kansas City
# 4894              shot         gun  31.0      M     White       Lawrence
#
#      state         flee  body_camera          arms_category  year
# ...

# %% [markdown]
# Process for stack area chart

# %%
df1 = pd.DataFrame(columns = ['year', 'total_case', 'unarmed_case'])
years = [2015,2016,2017,2018,2019]
for i in range(5):
    df1.loc[i] = {'year': years[i], 'total_case': len(main_data[main_data.year==years[i]]),\
                  'unarmed_case': len(main_data[(main_data.year==years[i])&(main_data.armed=='unarmed')])}
df1
# Out:
#    year total_case unarmed_case
# 0  2015        965           94
# 1  2016        904           51
# 2  2017        906           69
# 3  2018        888           57
# 4  2019        858           55

# %%
df1.to_csv('stack_area_chart_data.csv')

# %% [markdown]
# Process for map and bar chart

# %%
df2 = pd.DataFrame(columns = ['key', 'year', 'state', 'total_case', 'unarmed_case'])
years = [2015,2016,2017,2018,2019]
states = [ 'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
           'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
           'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
           'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']
for year in years:
    for state in states:
       df2 = df2.append({'key': str(year)+state, 'year': year, 'state': state, \
                    'total_case': len(main_data[(main_data.year==year)&(main_data.state==state)]), \
                   'unarmed_case': len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.armed=='unarmed')]) },\
                  ignore_index='True')
df2
# Out:
#         key  year state total_case unarmed_case
# 0    2015AK  2015    AK          4            0
# 1    2015AL  2015    AL         17            2
# 2    2015AR  2015    AR          4            1
# 3    2015AZ  2015    AZ         42            3
# 4    2015CA  2015    CA        182           22
# ..      ...   ...   ...        ...          ...
# 250  2019VT  2019    VT          2            0
# 251  2019WA  2019    WA         30            3
# 252  2019WI  2019    WI         17            1
# 253  2019WV  2019    WV         12            1
# 254  2019WY  2019    WY          1            0
#
# [255 rows x 5 columns]

# %%
df2.to_csv('map_and_bar_data.csv')

# %% [markdown]
# Recorded vs. Unrecorded, state wise and national

# %%
#State wise
df3 = pd.DataFrame(columns = ['key', 'year', 'state', 'recorded', 'unrecorded'])
years = [2015,2016,2017,2018,2019]
states = [ 'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
           'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
           'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
           'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']
for year in years:
    for state in states:
        df3 = df3.append({'key': str(year)+state, 'year': year, 'state': state, \
                    'recorded': len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.body_camera==True)]), \
                   'unrecorded': len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.body_camera==False)]) },\
                  ignore_index='True')
df3
# Out:
#         key  year state recorded unrecorded
# 0    2015AK  2015    AK        0          4
# 1    2015AL  2015    AL        3         14
# 2    2015AR  2015    AR        0          4
# 3    2015AZ  2015    AZ        2         40
# 4    2015CA  2015    CA       21        161
# ..      ...   ...   ...      ...        ...
# 250  2019VT  2019    VT        0          2
# 251  2019WA  2019    WA        4         26
# 252  2019WI  2019    WI        1         16
# 253  2019WV  2019    WV        1         11
# 254  2019WY  2019    WY        0          1
#
# [255 rows x 5 columns]

# %%
df3.to_csv('if_recorded_state_wise.csv')

# %%
#National
df4 = pd.DataFrame(columns = ['year','recorded', 'unrecorded'])
years = [2015,2016,2017,2018,2019]

for year in years:
        df4 = df4.append({'year': year,\
                    'recorded': len(main_data[(main_data.year==year)&(main_data.body_camera==True)]), \
                   'unrecorded': len(main_data[(main_data.year==year)&(main_data.body_camera==False)]) },\
                  ignore_index='True')
df4
# Out:
#    year recorded unrecorded
# 0  2015       74        891
# 1  2016      137        767
# 2  2017       99        807
# 3  2018      109        779
# 4  2019      121        737

# %%
df4.to_csv('if_recorded_national.csv')

# %% [markdown]
# Prepare for ethnicity, state wise vs. national

# %%
df5 = pd.DataFrame(columns = ['key', 'year', 'state', 'Asian', 'Black', 'Hispanic', 'Native', 'Other', 'White'])
years = [2015,2016,2017,2018,2019]
states = [ 'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
           'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
           'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
           'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']
for year in years:
    for state in states:
        df5 = df5.append({'key': str(year)+state, 'year': year, 'state': state, \
                    'Asian': len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Asian')]), \
                        'Black': len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Black')]) ,\
                         'Hispanic': len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Hispanic')]) ,\
                         'Native': len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Native')]) ,\
                         'Other': len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Other')]) ,\
                         'White': len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='White')]) },\
                  ignore_index='True')
df5
# Out:
#         key  year state Asian Black Hispanic Native Other White
# 0    2015AK  2015    AK     0     0        0      2     0     2
# 1    2015AL  2015    AL     0     6        0      0     0    11
# 2    2015AR  2015    AR     0     1        0      0     0     3
# 3    2015AZ  2015    AZ     0     1       12      2     0    27
# 4    2015CA  2015    CA     8    34       76      0     7    57
# ..      ...   ...   ...   ...   ...      ...    ...   ...   ...
# 250  2019VT  2019    VT     0     0        0      0     0     2
# 251  2019WA  2019    WA     2     8        8      1     0    11
# 252  2019WI  2019    WI     1     3        3      0     0    10
# 253  2019WV  2019    WV     1     2        0      0     0     9
# 254  2019WY  2019    WY     0     0        0      1     0     0
#
# [255 rows x 9 columns]

# %%
df5.to_csv('ethnicity_state_wise.csv')

# %%
#National
df6 = pd.DataFrame(columns = ['year','Asian', 'Black', 'Hispanic', 'Native', 'Other', 'White'])
years = [2015,2016,2017,2018,2019]

for year in years:
        df6 = df6.append({'year': year, \
                    'Asian': len(main_data[(main_data.year==year)&(main_data.race=='Asian')]), \
                        'Black': len(main_data[(main_data.year==year)&(main_data.race=='Black')]) ,\
                         'Hispanic': len(main_data[(main_data.year==year)&(main_data.race=='Hispanic')]) ,\
                         'Native': len(main_data[(main_data.year==year)&(main_data.race=='Native')]) ,\
                         'Other': len(main_data[(main_data.year==year)&(main_data.race=='Other')]) ,\
                         'White': len(main_data[(main_data.year==year)&(main_data.race=='White')]) },\
                  ignore_index='True')
df6
# Out:
#    year Asian Black Hispanic Native Other White
# 0  2015    14   258      172      9    15   497
# 1  2016    15   234      160     16    11   468
# 2  2017    16   224      179     22     6   459
# 3  2018    21   229      165     15     4   454
# 4  2019    19   250      163     13     9   404

# %%
df6.to_csv('ethnicity_national.csv')

# %% [markdown]
# Unarmed shootings proportion by ethnicity state wise vs. national

# %%
#state wise
df7 = pd.DataFrame(columns = ['key', 'year', 'state', 'Asian_proportion', 'Black_proportion', 'Hispanic_proportion', \
                              'Native_proportion', 'Other_proportion', 'White_proportion'])
years = [2015,2016,2017,2018,2019]
states = [ 'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
           'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
           'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
           'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']
for year in years:
    for state in states:
        df7 = df7.append({'key': str(year)+state, 'year': year, 'state': state, \
                    'Asian_proportion': 'N/A' if len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Asian')])==0 else len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Asian')&(main_data.armed=='unarmed')]) / len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Asian')]), \
                        'Black_proportion': 'N/A' if len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Black')])==0 else len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Black')&(main_data.armed=='unarmed')]) / len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Black')]) ,\
                         'Hispanic_proportion': 'N/A' if len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Hispanic')])==0 else len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Hispanic')&(main_data.armed=='unarmed')]) / len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Hispanic')]) ,\
                         'Native_proportion': 'N/A' if len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Native')])==0 else len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Native')&(main_data.armed=='unarmed')]) / len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Native')]) ,\
                         'Other_proportion': 'N/A' if len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Other')])==0 else len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Other')&(main_data.armed=='unarmed')]) / len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Other')]) ,\
                         'White_proportion': 'N/A' if len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='White')])==0 else len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='White')&(main_data.armed=='unarmed')]) / len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='White')]) },\
                  ignore_index='True')
df7
# Out:
#         key  year state Asian_proportion Black_proportion Hispanic_proportion  \
# 0    2015AK  2015    AK              N/A              N/A                 N/A
# 1    2015AL  2015    AL              N/A         0.166667                 N/A
# 2    2015AR  2015    AR              N/A                1                 N/A
# 3    2015AZ  2015    AZ              N/A                0           0.0833333
# 4    2015CA  2015    CA                0         0.147059            0.131579
# ..      ...   ...   ...              ...              ...                 ...
# 250  2019VT  2019    VT              N/A              N/A                 N/A
# 251  2019WA  2019    WA              0.5                0               0.125
# 252  2019WI  2019    WI                0                0                   0
# 253  2019WV  2019    WV                0                0                 N/A
# 254  2019WY  2019    WY              N/A              N/A                 N/A
#
# ...

# %%
df7.to_csv('unarmed_shooting_by_eth_state_wise.csv')

# %%
#state wise
df8 = pd.DataFrame(columns = ['year', 'Asian_proportion', 'Black_proportion', 'Hispanic_proportion', \
                              'Native_proportion', 'Other_proportion', 'White_proportion'])
years = [2015,2016,2017,2018,2019]

for year in years:
        df8 = df8.append({'year': year, \
                    'Asian_proportion': 'N/A' if len(main_data[(main_data.year==year)&(main_data.race=='Asian')])==0 else len(main_data[(main_data.year==year)&(main_data.race=='Asian')&(main_data.armed=='unarmed')]) / len(main_data[(main_data.year==year)&(main_data.race=='Asian')]), \
                        'Black_proportion': 'N/A' if len(main_data[(main_data.year==year)&(main_data.race=='Black')])==0 else len(main_data[(main_data.year==year)&(main_data.race=='Black')&(main_data.armed=='unarmed')]) / len(main_data[(main_data.year==year)&(main_data.race=='Black')]) ,\
                         'Hispanic_proportion': 'N/A' if len(main_data[(main_data.year==year)&(main_data.race=='Hispanic')])==0 else len(main_data[(main_data.year==year)&(main_data.race=='Hispanic')&(main_data.armed=='unarmed')]) / len(main_data[(main_data.year==year)&(main_data.race=='Hispanic')]) ,\
                         'Native_proportion': 'N/A' if len(main_data[(main_data.year==year)&(main_data.race=='Native')])==0 else len(main_data[(main_data.year==year)&(main_data.race=='Native')&(main_data.armed=='unarmed')]) / len(main_data[(main_data.year==year)&(main_data.race=='Native')]) ,\
                         'Other_proportion': 'N/A' if len(main_data[(main_data.year==year)&(main_data.race=='Other')])==0 else len(main_data[(main_data.year==year)&(main_data.race=='Other')&(main_data.armed=='unarmed')]) / len(main_data[(main_data.year==year)&(main_data.race=='Other')]) ,\
                         'White_proportion': 'N/A' if len(main_data[(main_data.year==year)&(main_data.race=='White')])==0 else len(main_data[(main_data.year==year)&(main_data.race=='White')&(main_data.armed=='unarmed')]) / len(main_data[(main_data.year==year)&(main_data.race=='White')]) },\
                  ignore_index='True')
df8
# Out:
#      year  Asian_proportion  Black_proportion  Hispanic_proportion  \
# 0  2015.0          0.000000          0.147287             0.110465
# 1  2016.0          0.000000          0.081197             0.056250
# 2  2017.0          0.062500          0.098214             0.072626
# 3  2018.0          0.047619          0.100437             0.048485
# 4  2019.0          0.210526          0.056000             0.067485
#
#    Native_proportion  Other_proportion  White_proportion
# 0           0.111111          0.266667          0.064386
# 1           0.062500          0.000000          0.047009
# 2           0.045455          0.166667          0.067538
# 3           0.000000          0.000000          0.055066
# 4           0.076923          0.000000          0.061881

# %%
df8.to_csv('unarmed_shooting_by_eth_national.csv')

# %%
us_state_to_abbrev = {
"Alabama": "AL",
"Alaska": "AK",
"Arizona": "AZ",
"Arkansas": "AR",
"California": "CA",
"Colorado": "CO",
"Connecticut": "CT",
"Delaware": "DE",
"Florida": "FL",
"Georgia": "GA",
"Hawaii": "HI",
"Idaho": "ID",
"Illinois": "IL",
"Indiana": "IN",
"Iowa": "IA",
"Kansas": "KS",
"Kentucky": "KY",
"Louisiana": "LA",
"Maine": "ME",
"Maryland": "MD",
"Massachusetts": "MA",
"Michigan": "MI",
"Minnesota": "MN",
"Mississippi": "MS",
"Missouri": "MO",
"Montana": "MT",
"Nebraska": "NE",
"Nevada": "NV",
"New Hampshire": "NH",
"New Jersey": "NJ",
"New Mexico": "NM",
"New York": "NY",
"North Carolina": "NC",
"North Dakota": "ND",
"Ohio": "OH",
"Oklahoma": "OK",
"Oregon": "OR",
"Pennsylvania": "PA",
"Rhode Island": "RI",
"South Carolina": "SC",
"South Dakota": "SD",
"Tennessee": "TN",
"Texas": "TX",
"Utah": "UT",
"Vermont": "VT",
"Virginia": "VA",
"Washington": "WA",
"West Virginia": "WV",
"Wisconsin": "WI",
"Wyoming": "WY",
"District of Columbia": "DC",
"American Samoa": "AS",
"Guam": "GU",
"Northern Mariana Islands": "MP",
"Puerto Rico": "PR",
"United States Minor Outlying Islands": "UM",
"U.S. Virgin Islands": "VI",
}
# invert the dictionary
abbrev_to_us_state = dict(map(reversed, us_state_to_abbrev.items()))
abbrev_to_us_state
# Out:
# {'AL': 'Alabama',
#  'AK': 'Alaska',
#  'AZ': 'Arizona',
#  'AR': 'Arkansas',
#  'CA': 'California',
#  'CO': 'Colorado',
#  'CT': 'Connecticut',
#  'DE': 'Delaware',
#  'FL': 'Florida',
#  'GA': 'Georgia',
#  'HI': 'Hawaii',
#  'ID': 'Idaho',
#  'IL': 'Illinois',
#  'IN': 'Indiana',
#  'IA': 'Iowa',
#  'KS': 'Kansas',
#  'KY': 'Kentucky',
#  'LA': 'Louisiana',
#  'ME': 'Maine',
#  'MD': 'Maryland',
#  'MA': 'Massachusetts',
#  'MI': 'Michigan',
#  'MN': 'Minnesota',
#  'MS': 'Mississippi',
#  'MO': 'Missouri',
#  'MT': 'Montana',
#  'NE': 'Nebraska',
#  'NV': 'Nevada',
#  'NH': 'New Hampshire',
#  'NJ': 'New Jersey',
#  'NM': 'New Mexico',
#  'NY': 'New York',
#  'NC': 'North Carolina',
#  'ND': 'North Dakota',
#  'OH': 'Ohio',
#  'OK': 'Oklahoma',
#  'OR': 'Oregon',
#  'PA': 'Pennsylvania',
#  'RI': 'Rhode Island',
#  'SC': 'South Carolina',
#  'SD': 'South Dakota',
#  'TN': 'Tennessee',
#  'TX': 'Texas',
#  'UT': 'Utah',
#  'VT': 'Vermont',
#  'VA': 'Virginia',
# ...

# %%
df9 = pd.DataFrame(columns = ['key', 'year', 'state_abbr', 'state', 'total_case', 'unarmed_case'])
years = [2015,2016,2017,2018,2019]
states = [ 'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
           'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
           'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
           'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']
for year in years:
    for state in states:
       df9 = df9.append({'key': str(year)+state, 'year': year, 'state_abbr': state, 'state': abbrev_to_us_state[state],\
                    'total_case': len(main_data[(main_data.year==year)&(main_data.state==state)]), \
                   'unarmed_case': len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.armed=='unarmed')]) },\
                  ignore_index='True')
df9
# Out:
#         key  year state_abbr          state total_case unarmed_case
# 0    2015AK  2015         AK         Alaska          4            0
# 1    2015AL  2015         AL        Alabama         17            2
# 2    2015AR  2015         AR       Arkansas          4            1
# 3    2015AZ  2015         AZ        Arizona         42            3
# 4    2015CA  2015         CA     California        182           22
# ..      ...   ...        ...            ...        ...          ...
# 250  2019VT  2019         VT        Vermont          2            0
# 251  2019WA  2019         WA     Washington         30            3
# 252  2019WI  2019         WI      Wisconsin         17            1
# 253  2019WV  2019         WV  West Virginia         12            1
# 254  2019WY  2019         WY        Wyoming          1            0
#
# [255 rows x 6 columns]

# %%
df9.to_csv('new_map_and_bar.csv')

# %%
#state wise
df10 = pd.DataFrame(columns = ['year', 'ethnicity', 'percentage'])
years = [2015,2016,2017,2018,2019]
ethnicities = ['Black', 'White', 'Asian', 'Hispanic','Native','Other']

for year in years:
    for ethnicity in ethnicities:
        df10 = df10.append({'year': year, 'ethnicity':ethnicity,\
                    'percentage': 'N/A' if len(main_data[(main_data.year==year)&(main_data.race==ethnicity)])==0 else len(main_data[(main_data.year==year)&(main_data.race==ethnicity)&(main_data.armed=='unarmed')]) / len(main_data[(main_data.year==year)&(main_data.race==ethnicity)])}, \
                  ignore_index='True')
df10
# Out:
# /var/folders/fg/0nl4vg_j3sv15xrf5tgrnbx40000gn/T/ipykernel_40606/1757657772.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df10 = df10.append({'year': year, 'ethnicity':ethnicity,\
# /var/folders/fg/0nl4vg_j3sv15xrf5tgrnbx40000gn/T/ipykernel_40606/1757657772.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df10 = df10.append({'year': year, 'ethnicity':ethnicity,\
# /var/folders/fg/0nl4vg_j3sv15xrf5tgrnbx40000gn/T/ipykernel_40606/1757657772.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df10 = df10.append({'year': year, 'ethnicity':ethnicity,\
# ...

# %%
df10.to_csv('new_unarmed_shooting_by_eth_national.csv')

# %%
#state wise
df11 = pd.DataFrame(columns = ['key', 'year', 'state_abbr', 'state', 'ethnicity', 'percentage'])
years = [2015,2016,2017,2018,2019]
states = [ 'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
           'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
           'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
           'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']
ethnicities = ['Black', 'White', 'Asian', 'Hispanic','Native','Other']
for year in years:
    for state in states:
        for ethnicity in ethnicities:
            df11 = df11.append({'key': str(year)+state, 'year': year, 'state_abbr': state, 'state':abbrev_to_us_state[state], 'ethnicity':ethnicity, \
                    'percentage': 'N/A' if len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race==ethnicity)])==0 else len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race==ethnicity)&(main_data.armed=='unarmed')]) / len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race==ethnicity)]), \
                        },\
                  ignore_index='True')
df11
# Out:
# /var/folders/fg/0nl4vg_j3sv15xrf5tgrnbx40000gn/T/ipykernel_40606/3825795737.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df11 = df11.append({'key': str(year)+state, 'year': year, 'state_abbr': state, 'state':abbrev_to_us_state[state], 'ethnicity':ethnicity, \
# /var/folders/fg/0nl4vg_j3sv15xrf5tgrnbx40000gn/T/ipykernel_40606/3825795737.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df11 = df11.append({'key': str(year)+state, 'year': year, 'state_abbr': state, 'state':abbrev_to_us_state[state], 'ethnicity':ethnicity, \
# /var/folders/fg/0nl4vg_j3sv15xrf5tgrnbx40000gn/T/ipykernel_40606/3825795737.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df11.to_csv('new_unarmed_shooting_by_eth_state_wise.csv')

# %%
#State wise
df12 = pd.DataFrame(columns = ['key', 'year', 'state_abbr', 'state', 'recorded', 'unrecorded'])
years = [2015,2016,2017,2018,2019]
states = [ 'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
           'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
           'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
           'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']
for year in years:
    for state in states:
        df12 = df12.append({'key': str(year)+state, 'year': year, 'state_abbr': state, 'state':abbrev_to_us_state[state],\
                    'recorded': len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.body_camera==True)]), \
                   'unrecorded': len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.body_camera==False)]) },\
                  ignore_index='True')
df12
# Out:
# /var/folders/fg/0nl4vg_j3sv15xrf5tgrnbx40000gn/T/ipykernel_40606/2044952025.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df12 = df12.append({'key': str(year)+state, 'year': year, 'state_abbr': state, 'state':abbrev_to_us_state[state],\
# /var/folders/fg/0nl4vg_j3sv15xrf5tgrnbx40000gn/T/ipykernel_40606/2044952025.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df12 = df12.append({'key': str(year)+state, 'year': year, 'state_abbr': state, 'state':abbrev_to_us_state[state],\
# /var/folders/fg/0nl4vg_j3sv15xrf5tgrnbx40000gn/T/ipykernel_40606/2044952025.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df12.to_csv('new_if_recorded_state_wise.csv')

# %%
df13 = pd.DataFrame(columns = ['key', 'year', 'state_abbr', 'state', 'Asian', 'Black', 'Hispanic', 'Native', 'Other', 'White'])
years = [2015,2016,2017,2018,2019]
states = [ 'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
           'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
           'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
           'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']
for year in years:
    for state in states:
        df13 = df13.append({'key': str(year)+state, 'year': year, 'state_abbr': state, 'state':abbrev_to_us_state[state], \
                    'Asian': len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Asian')]), \
                        'Black': len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Black')]) ,\
                         'Hispanic': len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Hispanic')]) ,\
                         'Native': len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Native')]) ,\
                         'Other': len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='Other')]) ,\
                         'White': len(main_data[(main_data.year==year)&(main_data.state==state)&(main_data.race=='White')]) },\
                  ignore_index='True')
df13
# Out:
# /var/folders/fg/0nl4vg_j3sv15xrf5tgrnbx40000gn/T/ipykernel_40606/3763247006.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df13 = df13.append({'key': str(year)+state, 'year': year, 'state_abbr': state, 'state':abbrev_to_us_state[state], \
# /var/folders/fg/0nl4vg_j3sv15xrf5tgrnbx40000gn/T/ipykernel_40606/3763247006.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df13 = df13.append({'key': str(year)+state, 'year': year, 'state_abbr': state, 'state':abbrev_to_us_state[state], \
# /var/folders/fg/0nl4vg_j3sv15xrf5tgrnbx40000gn/T/ipykernel_40606/3763247006.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df13.to_csv('new_ethnicity_state_wise.csv')
